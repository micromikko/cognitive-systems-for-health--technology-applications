# %% [markdown]
# # Ex1
# Use numpy arrays to create a x-vector from 0 to 1000. Calculate the
# value of log(x+1) and assign that to y-vector. Use matplotlib to create a
# plot of y vs. x. Annotate the graph with title, x- and y-labels.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(0,1001)
print(x)
# Out:
# [   0    1    2 ...,  998  999 1000]

# %%
y = np.log(x + 1)
print(y)
# Out:
# [ 0.          0.69314718  1.09861229 ...,  6.90675478  6.90775528
#   6.90875478]

# %%
fig = plt.plot(y, x)

plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0,0.5,'y')

# %% [markdown]
# # Ex2
# Use pandas to read data from:
# http://archive.ics.uci.edu/ml/machine-learning-databases/heart-
# disease/processed.switzerland.data
# Find out how to give the column names, and handle missing values.
# Plot a histogram of the age column.

# %% [markdown]
# ### Variables
# -- 1. #3  (age)
# -- 2. #4  (sex)
# -- 3. #9  (cp)
# -- 4. #10 (trestbps)
# -- 5. #12 (chol)
# -- 6. #16 (fbs)
# -- 7. #19 (restecg)
# -- 8. #32 (thalach)
# -- 9. #38 (exang)
# -- 10. #40 (oldpeak)
# -- 11. #41 (slope)
# -- 12. #44 (ca)
# -- 13. #51 (thal)
# -- 14. #58 (num)       (the predicted attribute)

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data', na_values="?")

# %%
df.columns=["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "num"]

# %%
print(df[:0])
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, num]
# Index: []

# %%
df.hist(column="age", grid=True, figsize=(20, 10), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002136B5CA7F0>]], dtype=object)
